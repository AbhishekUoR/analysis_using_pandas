# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Use the plot Method to Render a Line Chart

# %%
data.DataReader(name = "BB", data_source = "yahoo", start = "2007-01-01", end = "2020-12-31")
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2007-01-03  44.026669  41.703335  43.086666  42.849998  34739100.0  42.849998
# 2007-01-04  46.316666  42.423332  42.953335  46.189999  46007700.0  46.189999
# 2007-01-05  47.306667  45.166668  45.500000  47.099998  41453400.0  47.099998
# 2007-01-08  48.410000  46.606667  47.283333  47.386665  38547300.0  47.386665
# 2007-01-09  47.666668  43.263332  47.570000  43.666668  74142000.0  43.666668
# ...               ...        ...        ...        ...         ...        ...
# 2020-12-24   7.240000   7.050000   7.120000   7.060000   6088300.0   7.060000
# 2020-12-28   7.130000   6.850000   7.100000   6.880000   9820100.0   6.880000
# 2020-12-29   7.000000   6.680000   6.980000   6.770000  11284200.0   6.770000
# 2020-12-30   6.810000   6.600000   6.790000   6.670000   9434900.0   6.670000
# 2020-12-31   6.800000   6.630000   6.680000   6.630000   7530600.0   6.630000
#
# [3525 rows x 6 columns]

# %%
bb = data.DataReader(name = "BB", data_source = "yahoo", start = "2007-01-01", end = "2020-12-31")
bb.head(3)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2007-01-03  44.026669  41.703335  43.086666  42.849998  34739100.0  42.849998
# 2007-01-04  46.316666  42.423332  42.953335  46.189999  46007700.0  46.189999
# 2007-01-05  47.306667  45.166668  45.500000  47.099998  41453400.0  47.099998

# %%
bb.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb.plot(y = "High")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb["High"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Plot aesthetics with matplotlib

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
bb["High"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb["Close"]
# Out:
# Date
# 2007-01-03    42.849998
# 2007-01-04    46.189999
# 2007-01-05    47.099998
# 2007-01-08    47.386665
# 2007-01-09    43.666668
#                 ...
# 2020-12-24     7.060000
# 2020-12-28     6.880000
# 2020-12-29     6.770000
# 2020-12-30     6.670000
# 2020-12-31     6.630000
# Name: Close, Length: 3525, dtype: float64

# %%
def rank_pref(price):
    if price <= 10:
        return "Poor"
    elif price <= 50:
        return "Satisfactory"
    else:
        return "Stellar"
bb["Close"].apply(rank_pref)
# Out:
# Date
# 2007-01-03    Satisfactory
# 2007-01-04    Satisfactory
# 2007-01-05    Satisfactory
# 2007-01-08    Satisfactory
# 2007-01-09    Satisfactory
#                   ...
# 2020-12-24            Poor
# 2020-12-28            Poor
# 2020-12-29            Poor
# 2020-12-30            Poor
# 2020-12-31            Poor
# Name: Close, Length: 3525, dtype: object

# %%
bb["Close"].apply(rank_pref).value_counts()
# Out:
# Poor            1541
# Satisfactory    1125
# Stellar          859
# Name: Close, dtype: int64

# %%
bb["Close"].apply(rank_pref).value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
bb["Close"].apply(rank_pref).value_counts().plot(kind = "line")
# Out:
# <AxesSubplot:>

# %%
bb["Close"].apply(rank_pref).value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
bb["Close"].apply(rank_pref).value_counts().plot(kind = "barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Creating Pie Charts to Represent Proportions

# %%
bb["Close"].mean()
# Out:
# 29.452764073094578

# %%
def rank_perf(price):
    if price >= 29.452764073094578:
        return "Above Average"
    else:
        return "Below Average"
bb["Close"].apply(rank_perf)
# Out:
# Date
# 2007-01-03    Above Average
# 2007-01-04    Above Average
# 2007-01-05    Above Average
# 2007-01-08    Above Average
# 2007-01-09    Above Average
#                   ...
# 2020-12-24    Below Average
# 2020-12-28    Below Average
# 2020-12-29    Below Average
# 2020-12-30    Below Average
# 2020-12-31    Below Average
# Name: Close, Length: 3525, dtype: object

# %%
plt.style.use('dark_background')

# %%
bb["Close"].apply(rank_perf).value_counts().plot(kind = "pie", legend = True)
# Out:
# <AxesSubplot:ylabel='Close'>
