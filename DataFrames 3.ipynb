# %%
import pandas as pd

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# # set_index() and reset_index()

# %%
bond.set_index("Film")
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.set_index("Film", inplace = True)

# %%
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.reset_index()
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond.reset_index(drop = True)
# Out:
#     Year           Actor            Director  Box Office  Budget  \
# 0   1962    Sean Connery       Terence Young       448.8     7.0
# 1   1963    Sean Connery       Terence Young       543.8    12.6
# 2   1964    Sean Connery        Guy Hamilton       820.4    18.6
# 3   1965    Sean Connery       Terence Young       848.1    41.9
# 4   1967     David Niven          Ken Hughes       315.0    85.0
# 5   1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 6   1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 7   1971    Sean Connery        Guy Hamilton       442.5    34.7
# 8   1973     Roger Moore        Guy Hamilton       460.3    30.8
# 9   1974     Roger Moore        Guy Hamilton       334.0    27.7
# 10  1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 11  1979     Roger Moore       Lewis Gilbert       535.0    91.5
# 12  1981     Roger Moore           John Glen       449.4    60.2
# ...

# %%
bond.reset_index(drop = True, inplace = True)
bond.head()
# Out:
#    Year         Actor       Director  Box Office  Budget  Bond Actor Salary
# 0  1962  Sean Connery  Terence Young       448.8     7.0                0.6
# 1  1963  Sean Connery  Terence Young       543.8    12.6                1.6
# 2  1964  Sean Connery   Guy Hamilton       820.4    18.6                3.2
# 3  1965  Sean Connery  Terence Young       848.1    41.9                4.7
# 4  1967   David Niven     Ken Hughes       315.0    85.0                NaN

# %%
bond.set_index("Year", inplace = True)

# %%
bond.set_index("Actor")
# Out:
#                           Director  Box Office  Budget  Bond Actor Salary
# Actor
# Sean Connery         Terence Young       448.8     7.0                0.6
# Sean Connery         Terence Young       543.8    12.6                1.6
# Sean Connery          Guy Hamilton       820.4    18.6                3.2
# Sean Connery         Terence Young       848.1    41.9                4.7
# David Niven             Ken Hughes       315.0    85.0                NaN
# Sean Connery         Lewis Gilbert       514.2    59.9                4.4
# George Lazenby       Peter R. Hunt       291.5    37.3                0.6
# Sean Connery          Guy Hamilton       442.5    34.7                5.8
# Roger Moore           Guy Hamilton       460.3    30.8                NaN
# Roger Moore           Guy Hamilton       334.0    27.7                NaN
# Roger Moore          Lewis Gilbert       533.0    45.1                NaN
# Roger Moore          Lewis Gilbert       535.0    91.5                NaN
# ...

# %%
bond.reset_index(inplace = True)
bond.set_index("Actor", inplace = True)
bond.head()
# Out:
#               Year       Director  Box Office  Budget  Bond Actor Salary
# Actor
# Sean Connery  1962  Terence Young       448.8     7.0                0.6
# Sean Connery  1963  Terence Young       543.8    12.6                1.6
# Sean Connery  1964   Guy Hamilton       820.4    18.6                3.2
# Sean Connery  1965  Terence Young       848.1    41.9                4.7
# David Niven   1967     Ken Hughes       315.0    85.0                NaN

# %% [markdown]
# # .loc[] Accessor

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.loc["Dr. No"]
# Out:
# Year                          1962
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   448.8
# Budget                         7.0
# Bond Actor Salary              0.6
# Name: Dr. No, dtype: object

# %%
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["A View to a Kill" : "Diamonds Are Forever"]
# Out:
#                       Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill      1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale         2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale         1967   David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971  Sean Connery     Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8

# %%
bond.loc["A View to a Kill" : "Diamonds Are Forever" : 2]
# Out:
#                   Year        Actor    Director  Box Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore   John Glen       275.2    54.5
# Casino Royale     1967  David Niven  Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   NaN

# %%
film_list = ["Diamonds Are Forever", "A View to a Kill"]
bond.loc[film_list]
# Out:
#                       Year         Actor      Director  Box Office  Budget  \
# Film
# Diamonds Are Forever  1971  Sean Connery  Guy Hamilton       442.5    34.7
# A View to a Kill      1985   Roger Moore     John Glen       275.2    54.5
#
#                       Bond Actor Salary
# Film
# Diamonds Are Forever                5.8
# A View to a Kill                    9.1

# %% [markdown]
# # iloc[]

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.iloc[0: 5 : 2]
# Out:
#                   Year           Actor      Director  Box Office  Budget  \
# Film
# A View to a Kill  1985     Roger Moore     John Glen       275.2    54.5
# Casino Royale     1967     David Niven    Ken Hughes       315.0    85.0
# Die Another Day   2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   NaN
# Die Another Day                17.9

# %% [markdown]
# # Second arguments to loc[] and iloc[]

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["A View to a Kill", "Year"]
# Out:
# 1985

# %%
bond.loc["A View to a Kill", ["Year", "Actor"]]
# Out:
# Year            1985
# Actor    Roger Moore
# Name: A View to a Kill, dtype: object

# %%
bond.loc["A View to a Kill":"Casino Royale", ["Year", "Actor"]]
# Out:
#                   Year         Actor
# Film
# A View to a Kill  1985   Roger Moore
# Casino Royale     2006  Daniel Craig
# Casino Royale     1967   David Niven

# %%
bond.iloc[0: 5 : 2, 0:2]
# Out:
#                   Year           Actor
# Film
# A View to a Kill  1985     Roger Moore
# Casino Royale     1967     David Niven
# Die Another Day   2002  Pierce Brosnan

# %% [markdown]
# # Set new value to specific cell and range of cell in same row

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.loc["Dr. No", "Actor"]
# Out:
# 'Sean Connery'

# %%
bond.loc["Dr. No", "Actor"] = "Abhishek"
bond.loc["Dr. No", "Actor"]
# Out:
# 'Abhishek'

# %%
bond.loc["Dr. No", ["Actor", "Budget"]] = ["Sean Connery" , 2300]

# %%
bond.loc["Dr. No", ["Actor", "Budget"]]
# Out:
# Actor     Sean Connery
# Budget          2300.0
# Name: Dr. No, dtype: object

# %% [markdown]
# # Set multiple values in DataFrames

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
actor_sean_connery = bond["Actor"] == "Sean Connery"
actor_sean_connery.head()
# Out:
# Film
# A View to a Kill        False
# Casino Royale           False
# Casino Royale           False
# Diamonds Are Forever     True
# Die Another Day         False
# Name: Actor, dtype: bool

# %%
bond.loc[actor_sean_connery]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.loc[actor_sean_connery, "Actor"]  = "Sir Sean Connery"

# %%
bond.head()
# Out:
#                       Year             Actor         Director  Box Office  \
# Film
# A View to a Kill      1985       Roger Moore        John Glen       275.2
# Casino Royale         2006      Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967       David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971  Sir Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002    Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %% [markdown]
# # rename() index label and column

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename(mapper = {"A View to a Kill": "View to a Kill"}, axis = "rows")
bond.rename(mapper = {"A View to a Kill": "View to a Kill"}, axis = 0)
bond.rename(mapper = {"A View to a Kill": "View to a Kill"}, axis = "index")
bond.rename(mapper = {"A View to a Kill": "View to a Kill"})
bond.rename(index = {"A View to a Kill": "View to a Kill"}, inplace = True)

# %%
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# View to a Kill        1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# View to a Kill          54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename(mapper = {"Actor": "Hero"}, axis = "columns")
bond.rename(mapper = {"Actor": "Hero"}, axis = 1)
bond.rename(columns = {"Actor": "Hero"}, inplace = True)

# %%
bond.head()
# Out:
#                       Year            Hero         Director  Box Office  \
# Film
# View to a Kill        1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# View to a Kill          54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.columns
# Out:
# Index(['Year', 'Hero', 'Director', 'Box Office', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
new_col = ['Year', 'Hero', 'Director', 'Box Office', 'Budget',
       'Salary']
bond.columns = new_col
bond.columns
# Out:
# Index(['Year', 'Hero', 'Director', 'Box Office', 'Budget', 'Salary'], dtype='object')

# %% [markdown]
# # Delete row or columns from df

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.drop("A View to a Kill")
bond.drop("A View to a Kill", axis = 0)
bond.drop("A View to a Kill", axis = "rows", inplace = True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                1962    Sean Connery    Terence Young       448.8
#
#                       Budget  Bond Actor Salary
# Film
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9
# Dr. No                   7.0                0.6

# %%
bond.drop("Year", axis = 1)
bond.drop("Year", axis = "columns", inplace = True)
bond.head()
# Out:
#                                Actor         Director  Box Office  Budget  \
# Film
# Casino Royale           Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale            David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever    Sean Connery     Guy Hamilton       442.5    34.7
# Die Another Day       Pierce Brosnan     Lee Tamahori       465.4   154.2
# Dr. No                  Sean Connery    Terence Young       448.8     7.0
#
#                       Bond Actor Salary
# Film
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Die Another Day                    17.9
# Dr. No                              0.6

# %%
bond.pop("Actor")
# Out:
# Film
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# The Living Daylights               Timothy Dalton
# ...

# %%
bond.head()
# Out:
#                              Director  Box Office  Budget  Bond Actor Salary
# Film
# Casino Royale         Martin Campbell       581.5   145.3                3.3
# Casino Royale              Ken Hughes       315.0    85.0                NaN
# Diamonds Are Forever     Guy Hamilton       442.5    34.7                5.8
# Die Another Day          Lee Tamahori       465.4   154.2               17.9
# Dr. No                  Terence Young       448.8     7.0                0.6

# %%
del(bond["Director"])

# %%
bond.head()
# Out:
#                       Box Office  Budget  Bond Actor Salary
# Film
# Casino Royale              581.5   145.3                3.3
# Casino Royale              315.0    85.0                NaN
# Diamonds Are Forever       442.5    34.7                5.8
# Die Another Day            465.4   154.2               17.9
# Dr. No                     448.8     7.0                0.6

# %% [markdown]
# #  Create Random Sample

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.sample()
# Out:
#                      Year         Actor       Director  Box Office  Budget  \
# Film
# You Only Live Twice  1967  Sean Connery  Lewis Gilbert       514.2    59.9
#
#                      Bond Actor Salary
# Film
# You Only Live Twice                4.4

# %%
bond.sample(n = 5)
# Out:
#                              Year           Actor            Director  \
# Film
# Tomorrow Never Dies          1997  Pierce Brosnan  Roger Spottiswoode
# For Your Eyes Only           1981     Roger Moore           John Glen
# The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# Moonraker                    1979     Roger Moore       Lewis Gilbert
# Goldfinger                   1964    Sean Connery        Guy Hamilton
#
#                              Box Office  Budget  Bond Actor Salary
# Film
# Tomorrow Never Dies               463.2   133.9               10.0
# For Your Eyes Only                449.4    60.2                NaN
# The Man with the Golden Gun       334.0    27.7                NaN
# Moonraker                         535.0    91.5                NaN
# Goldfinger                        820.4    18.6                3.2

# %%
bond.sample(frac = 0.1)
# Out:
#                       Year           Actor       Director  Box Office  Budget  \
# Film
# The Living Daylights  1987  Timothy Dalton      John Glen       313.5    68.8
# Thunderball           1965    Sean Connery  Terence Young       848.1    41.9
# Goldfinger            1964    Sean Connery   Guy Hamilton       820.4    18.6
#
#                       Bond Actor Salary
# Film
# The Living Daylights                5.2
# Thunderball                         4.7
# Goldfinger                          3.2

# %%
bond.sample(n = 2, axis = "columns")
# Out:
#                                            Director  Box Office
# Film
# Dr. No                                Terence Young       448.8
# From Russia with Love                 Terence Young       543.8
# Goldfinger                             Guy Hamilton       820.4
# Thunderball                           Terence Young       848.1
# Casino Royale                            Ken Hughes       315.0
# You Only Live Twice                   Lewis Gilbert       514.2
# On Her Majesty's Secret Service       Peter R. Hunt       291.5
# Diamonds Are Forever                   Guy Hamilton       442.5
# Live and Let Die                       Guy Hamilton       460.3
# The Man with the Golden Gun            Guy Hamilton       334.0
# The Spy Who Loved Me                  Lewis Gilbert       533.0
# Moonraker                             Lewis Gilbert       535.0
# For Your Eyes Only                        John Glen       449.4
# Never Say Never Again                Irvin Kershner       380.0
# ...

# %%
bond.sample(n = 2, axis = 1)
# Out:
#                                  Budget            Director
# Film
# Dr. No                              7.0       Terence Young
# From Russia with Love              12.6       Terence Young
# Goldfinger                         18.6        Guy Hamilton
# Thunderball                        41.9       Terence Young
# Casino Royale                      85.0          Ken Hughes
# You Only Live Twice                59.9       Lewis Gilbert
# On Her Majesty's Secret Service    37.3       Peter R. Hunt
# Diamonds Are Forever               34.7        Guy Hamilton
# Live and Let Die                   30.8        Guy Hamilton
# The Man with the Golden Gun        27.7        Guy Hamilton
# The Spy Who Loved Me               45.1       Lewis Gilbert
# Moonraker                          91.5       Lewis Gilbert
# For Your Eyes Only                 60.2           John Glen
# Never Say Never Again              86.0      Irvin Kershner
# Octopussy                          53.9           John Glen
# ...

# %% [markdown]
# # nsmallest() and nlargest()

# %%
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.nlargest(n = 4, columns = "Year")
# Out:
#                    Year         Actor         Director  Box Office  Budget  \
# Film
# Spectre            2015  Daniel Craig       Sam Mendes       726.7   206.3
# Skyfall            2012  Daniel Craig       Sam Mendes       943.5   170.2
# Quantum of Solace  2008  Daniel Craig     Marc Forster       514.2   181.4
# Casino Royale      2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                    Bond Actor Salary
# Film
# Spectre                          NaN
# Skyfall                         14.5
# Quantum of Solace                8.1
# Casino Royale                    3.3

# %%
bond.nsmallest(n = 4, columns = "Year")
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7

# %%
bond["Budget"].nsmallest(3)
# Out:
# Film
# Dr. No                    7.0
# From Russia with Love    12.6
# Goldfinger               18.6
# Name: Budget, dtype: float64

# %%
bond["Budget"].nlargest(3)
# Out:
# Film
# Spectre              206.3
# Quantum of Solace    181.4
# Skyfall              170.2
# Name: Budget, dtype: float64

# %% [markdown]
# # where()

# %%
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.where(bond["Actor"] == "Sean Connery")
# Out:
#                                    Year         Actor        Director  \
# Film
# Dr. No                           1962.0  Sean Connery   Terence Young
# From Russia with Love            1963.0  Sean Connery   Terence Young
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Thunderball                      1965.0  Sean Connery   Terence Young
# Casino Royale                       NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
# On Her Majesty's Secret Service     NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Live and Let Die                    NaN           NaN             NaN
# The Man with the Golden Gun         NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# Moonraker                           NaN           NaN             NaN
# ...

# %%
bond.where((bond["Actor"] == "Sean Connery") & (bond["Director"] == "Terence Young"))
# Out:
#                                    Year         Actor       Director  \
# Film
# Dr. No                           1962.0  Sean Connery  Terence Young
# From Russia with Love            1963.0  Sean Connery  Terence Young
# Goldfinger                          NaN           NaN            NaN
# Thunderball                      1965.0  Sean Connery  Terence Young
# Casino Royale                       NaN           NaN            NaN
# You Only Live Twice                 NaN           NaN            NaN
# On Her Majesty's Secret Service     NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# The Man with the Golden Gun         NaN           NaN            NaN
# The Spy Who Loved Me                NaN           NaN            NaN
# Moonraker                           NaN           NaN            NaN
# ...

# %% [markdown]
# # query()

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %% [markdown]
# # query()

# %%
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.query("Actor == 'Sean Connery'")
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# You Only Live Twice                  4.4
# Diamonds Are Forever                 5.8
# ...

# %%
bond.query("Actor == 'Sean Connery' and Director == 'Guy Hamilton'")
# Out:
#                       Year         Actor      Director  Box Office  Budget  \
# Film
# Goldfinger            1964  Sean Connery  Guy Hamilton       820.4    18.6
# Diamonds Are Forever  1971  Sean Connery  Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# Goldfinger                          3.2
# Diamonds Are Forever                5.8

# %%
bond.query("Actor == 'Sean Connery' and Director == 'Guy Hamilton'")
# Out:
#                       Year         Actor      Director  Box Office  Budget  \
# Film
# Goldfinger            1964  Sean Connery  Guy Hamilton       820.4    18.6
# Diamonds Are Forever  1971  Sean Connery  Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# Goldfinger                          3.2
# Diamonds Are Forever                5.8

# %%
bond.columns[0]
# Out:
# 'Year'

# %%
new_names = []
for names in bond.columns:
    new_names.append(names.replace(" ", "_"))
new_names
# Out:
# ['Year', 'Actor', 'Director', 'Box_Office', 'Budget', 'Bond_Actor_Salary']

# %%
bond.columns = new_names

# %%
bond.columns
# Out:
# Index(['Year', 'Actor', 'Director', 'Box_Office', 'Budget',
#        'Bond_Actor_Salary'],
#       dtype='object')

# %% [markdown]
# # apply() on rows

# %%
bond.head()
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
def movie_review(row):
    if row[1] == "Sean Connery":
        return "best"
    else:
        return "good"
    
bond.apply(movie_review, axis = "columns")
# Out:
# Film
# Dr. No                             best
# From Russia with Love              best
# Goldfinger                         best
# Thunderball                        best
# Casino Royale                      good
# You Only Live Twice                best
# On Her Majesty's Secret Service    good
# Diamonds Are Forever               best
# Live and Let Die                   good
# The Man with the Golden Gun        good
# The Spy Who Loved Me               good
# Moonraker                          good
# For Your Eyes Only                 good
# Never Say Never Again              best
# Octopussy                          good
# A View to a Kill                   good
# The Living Daylights               good
# Licence to Kill                    good
# GoldenEye                          good
# Tomorrow Never Dies                good
# The World Is Not Enough            good
# Die Another Day                    good
# Casino Royale                      good
# ...
